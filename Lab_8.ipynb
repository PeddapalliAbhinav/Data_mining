# %% [markdown]
# <a href="https://colab.research.google.com/github/PeddapalliAbhinav/Data_mining/blob/main/Lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('multiple_linear_regression_data.csv')

# %%
df.head(10)
# Out:
#          X1        X2        X3          Y
# 0  3.745401  0.314292  6.420316   5.490043
# 1  9.507143  6.364104  0.841400  39.756637
# 2  7.319939  3.143560  1.616287  28.774595
# 3  5.986585  5.085707  8.985542  19.779545
# 4  1.560186  9.075665  6.064291  14.742456
# 5  1.559945  2.492922  0.091971   9.760164
# 6  0.580836  4.103829  1.014715   8.273665
# 7  8.661761  7.555511  6.635018  35.313723
# 8  6.011150  2.287982  0.050616  21.766277
# 9  7.080726  0.769799  1.608081  21.058959

# %%
X = df[['X1', 'X2', 'X3']]
Y = df['Y']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
print(f'Coefficients: {model.coef_}')
print(f"Intercept: {model.intercept_}")
# Out:
# Coefficients: [ 3.06640394  2.04207702 -0.95747806]
# Intercept: -0.48558106749295504

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print(f"Mean Squared Error: {mse}")
print(f"R-squared Score: {r2}")
# Out:
# Mean Squared Error: 2.101579561196285
# R-squared Score: 0.9813470711033213

# %%
plt.scatter(y_test, y_pred, color="blue", alpha=0.5)
plt.scatter(y_test,y_test, color="red", alpha=0.5)
plt.xlabel("Actual Sales")
plt.ylabel("Predicted Sales")
plt.title("Actual vs. Predicted Sales")
plt.show()

# %%
#eXTRA PART

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

svr_model = SVR(kernel='rbf')
svr_model.fit(X_train_scaled, y_train)

# Make predictions with SVR
y_pred_svr = svr_model.predict(X_test_scaled)

# Evaluate both models
mse_lr = mean_squared_error(y_test, y_pred)
r2_lr = r2_score(y_test, y_pred)

mse_svr = mean_squared_error(y_test, y_pred_svr)
r2_svr = r2_score(y_test, y_pred_svr)

# Print results
print("Linear Regression:")
print(f"Mean Squared Error: {mse_lr}")
print(f"R-squared Score: {r2_lr}\n")

print("Support Vector Regression:")
print(f"Mean Squared Error: {mse_svr}")
print(f"R-squared Score: {r2_svr}")
# Out:
# Linear Regression:
# Mean Squared Error: 2.101579561196285
# R-squared Score: 0.9813470711033213
#
# Support Vector Regression:
# Mean Squared Error: 21.821347265103373
# R-squared Score: 0.8063208995361513
